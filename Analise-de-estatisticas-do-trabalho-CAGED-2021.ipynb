# %%
#Trabalho feito por Kevin Gabriel Alves Melo e Luiz Miguel Macedo Andre 3°A ADS

# %%
import pandas as pd
low_memory = False
import matplotlib.pyplot as plt
# %matplotlib inline
pd.options.display.max_columns = 80
pd.options.display.max_rows = 90
#Import de bibliotecas

# %%
dados = r"C:\Python\bdEstatisticaTrabalho.xlsx"

df = pd.read_excel(dados)
df1 = pd.read_excel(dados, 'Página1')
#Abrindo o excel da base de dados

# %%
df1.columns
# Out:
# Index(['uf', 'cod_municipio', 'municipio', 'estoque_fev_2020',
#        'admissoes_fev_2020', 'desligamentos_fev_2020', 'saldos_fev_2020',
#        'variacao_fev_2020', 'estoque_mar_2020', 'admissoes_mar_2020',
#        ...
#        'admissoes_acumulado_2021', 'desligamentos_acumulado_2021',
#        'saldos_acumulado_2021', 'variacao_acumulado_2021',
#        'admissioes_mar20-fev21', 'desligamentos_mar20-fev21',
#        'saldos_mar20-fev21', 'variacao_mar20-fev21', 'coluna-vazia1',
#        'coluna-vazia2'],
#       dtype='object', length=128)

# %%
avp=df.query('uf == "SP"')  #nomendo a váriavel avp = SP
avp.groupby('municipio')['admissoes_fev_2021'].max().sort_values().tail(20).plot(kind='pie',figsize=(10,10))  #Criando o gráfico de pizza para admissôes no estado São Paulo em fevereiro de 2021
# Out:
# <AxesSubplot:ylabel='admissoes_fev_2021'>

# %%
avp=df.query('uf == "SP"')  #nomendo a váriavel avp = SP
avp.groupby('municipio')['desligamentos_fev_2021'].max().sort_values().tail(20).plot(kind='pie',figsize=(10,10))  #Criando o gráfico de pizza para demissões no estado São Paulo em fevereiro de 2021
# Out:
# <AxesSubplot:ylabel='desligamentos_fev_2021'>

# %%
avp=df.query('uf == "SP"')  #nomendo a váriavel avp = SP
avp.groupby('municipio')['saldos_fev_2021'].max().sort_values().tail(20).plot(kind='barh',figsize=(10,10))  #Criando o gráfico de barras horizontais para saldos no estado São Paulo em fevereiro de 2021
# Out:
# <AxesSubplot:ylabel='municipio'>

# %%
avp=df.query('uf == "RJ"')  #nomendo a váriavel avp = RJ
avp.groupby('municipio')['admissoes_fev_2021'].max().sort_values().tail(20).plot(kind='pie',figsize=(10,10))  #Criando o gráfico de pizza para admissôes no estado Rio de Janeiro em fevereiro de 2021
# Out:
# <AxesSubplot:ylabel='admissoes_fev_2021'>

# %%
avp=df.query('uf == "RJ"')  #nomendo a váriavel avp = RJ
avp.groupby('municipio')['desligamentos_fev_2021'].max().sort_values().tail(20).plot(kind='pie',figsize=(10,10))  #Criando o gráfico de barras para admissôes no estado Rio de Janeiro em fevereiro de 2021
# Out:
# <AxesSubplot:ylabel='desligamentos_fev_2021'>

# %%
avp=df.query('uf == "RJ"')  #nomendo a váriavel avp = RJ
avp.groupby('municipio')['saldos_fev_2021'].max().sort_values().tail(20).plot(kind='barh',figsize=(10,10))  #Criando o gráfico de barras para admissôes no estado do Rio de Janeiro em fevereiro de 2021
# Out:
# <AxesSubplot:ylabel='municipio'>

# %%
avp=df.query('uf == "SP"')  #nomendo a váriavel avp = SP
avp.groupby('municipio')['desligamentos_mar20-fev21'].max().sort_values().tail(20).plot(kind='barh',figsize=(10,10))  #Criando o gráfico de barras horizontais para demissões no estado de São Paulo ao decorrer de marc/20 até fev/21
#Valor em escala de milhões
# Out:
# <AxesSubplot:ylabel='municipio'>

# %%
avp=df.query('uf == "SP"')  #nomendo a váriavel avp = SP
avp.groupby('municipio')['saldos_mar20-fev21'].max().sort_values().tail(20).plot(kind='pie',figsize=(10,10))  #Criando o gráfico de pizza para o saldo no estado de SP ao decorrer de marc/20 até fev/21
# Out:
# <AxesSubplot:ylabel='saldos_mar20-fev21'>

# %%
avp=df.query('uf == "RJ"')  #nomendo a váriavel avp = RJ
avp.groupby('municipio')['desligamentos_mar20-fev21'].max().sort_values().tail(20).plot(kind='barh',figsize=(10,10))  #Criando o gráfico de barras horizontais para demissões no estado de Rio de Janeiro ao decorrer de marc/20 até fev/21
# Out:
# <AxesSubplot:ylabel='municipio'>

# %%
avp=df.query('uf == "RJ"')  #nomendo a váriavel avp = RJ
avp.groupby('municipio')['saldos_mar20-fev21'].max().sort_values().tail(20).plot(kind='pie',figsize=(10,10))  #Criando o gráfico de pizza para o saldo no estado de Rio de Janeiro ao decorrer de marc/20 até fev/21
# Out:
# <AxesSubplot:ylabel='saldos_mar20-fev21'>

# %%
avp=df.query('uf == "AM"')  #nomendo a váriavel avp = AM
avp.groupby('municipio')['desligamentos_mar20-fev21'].max().sort_values().tail(20).plot(kind='barh',figsize=(10,10))  #Criando o gráfico de barras horizontais para demissões no estado de Manaus ao decorrer de marc/20 até fev/21
# Out:
# <AxesSubplot:ylabel='municipio'>

# %%
avp=df.query('uf == "AM"')  #nomendo a váriavel avp = AM
avp.groupby('municipio')['saldos_mar20-fev21'].max().sort_values().tail(20).plot(kind='bar',figsize=(10,10))  #Criando o gráfico de barra para saldos no estado de Manaus ao decorrer de marc/20 até fev/21
# Out:
# <AxesSubplot:xlabel='municipio'>
